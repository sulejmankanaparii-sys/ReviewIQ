# %% [markdown]
# <a href="https://colab.research.google.com/github/sulejmankanaparii-sys/ReviewIQ/blob/main/notebooks/01_eda_and_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install required libraries
# !pip install kaggle pandas numpy matplotlib seaborn wordcloud -q

# %%
# ── Imports ──────────────────────────────────────────
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
import warnings
warnings.filterwarnings('ignore')

# Plot settings
plt.rcParams['figure.figsize'] = (12, 5)
plt.rcParams['font.size'] = 12
sns.set_style('whitegrid')

print("✅ All libraries imported successfully!")
# Out:
# ✅ All libraries imported successfully!

# %%
# ── Load Dataset from Kaggle ─────────────────────────
import kagglehub

# Download the dataset
path = kagglehub.dataset_download("snap/amazon-fine-food-reviews")
print(f"✅ Dataset downloaded to: {path}")

# Load into DataFrame
df = pd.read_csv(f"{path}/Reviews.csv")
print(f"✅ Dataset loaded successfully!")
print(f"📊 Shape: {df.shape[0]:,} rows × {df.shape[1]} columns")
# Out:
# Using Colab cache for faster access to the 'amazon-fine-food-reviews' dataset.
# ✅ Dataset downloaded to: /kaggle/input/amazon-fine-food-reviews
# ✅ Dataset loaded successfully!
# 📊 Shape: 568,454 rows × 10 columns

# %% [markdown]
# # ReviewIQ – AI-Powered Review Intelligence System
# ## Notebook 01: Dataset Analysis & Exploratory Data Analysis (EDA)
#
# **Dataset:** Amazon Fine Food Reviews
# **Source:** https://www.kaggle.com/datasets/snap/amazon-fine-food-reviews
# **Author:** [Emri yt]
# **Role:** Dataset Analysis, EDA, Business Problem, Labeling
#
# ### Business Problem
# Amazon products show an average rating (e.g. 4.6/5) but customers never read
# the actual reviews. ReviewIQ solves this by automatically analyzing review text
# and breaking down sentiment by aspect: Quality, Price, Packaging, and Taste/Smell.
